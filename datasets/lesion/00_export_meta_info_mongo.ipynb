# %%
# this script prepares the table for the 

import os
import sys
import ast
import pandas as pd
import numpy as np 

sys.path.append('/home/oleksii/projects/ohif-orthanc-postgres-docker/')
from utils.utils import get_orthanc_client

orthanc_client = get_orthanc_client()

# Read the segmentation.csv file
segmentation_path = '/data/oleksii/alta-ai.com/alta-ai-orthanc-backup/export20240814/mongo_csv_dump/aggregatedData/segmentation.csv'
df = pd.read_csv(segmentation_path)

df = df[df["segmentType"] == 'lesion']

# Function to extract and join information from the 'segments' column
def extract_segment_info(segments):
    try:
        segments_list = ast.literal_eval(segments)
        info = {
            'segment_id': ','.join(str(i) for i in range(1, len(segments_list)+1)),
            'volume': ','.join(str(segment['generalInfo'].get('voxelVolume', '')) for segment in segments_list),
            'zone': ','.join(segment['detailInfo'].get('zone', '') for segment in segments_list),
            'region': ','.join(segment['detailInfo'].get('region', '') for segment in segments_list),
            'class': ','.join(segment['detailInfo'].get('diagnosticClass', '') for segment in segments_list),
            'laterality': ','.join(segment['detailInfo'].get('laterality', '') for segment in segments_list),
            'trackingUID': ','.join(segment.get('trackingUID', '') for segment in segments_list)
        }
        return pd.Series(info)
    except (ValueError, SyntaxError, KeyError) as e:
        print(f"Error parsing segments: {e}")
        return pd.Series({
            'segment_id': '', 'volume': '', 'zone': '', 'region': '', 'class': '', 'laterality': '', 'trackingUID': ''
        })

# Apply the function to create new columns with joined segment information
result_df = df.join(df['segments'].apply(extract_segment_info))

# Rename columns to match segments_copy.csv format
result_df = result_df.rename(columns={
    'studyInstanceUID': 'study_uid',
    'seriesInstanceUID': 'series_uid'
})

# Function to safely extract confidenceLevel
def get_confidence_level(editing_info):
    try:
        info = ast.literal_eval(editing_info)
        return info.get('confidenceLevel', '')
    except (ValueError, SyntaxError):
        return ''

result_df['confidence'] = df['editingInfo'].apply(get_confidence_level)
result_df = result_df[result_df["confidence"] == 'perfect']

# Add comment column
result_df['comment'] = ''

# Normalize 'class' values
def normalize_class(class_string):
    class_map = {
        'Chronic inflammation': 'CI',
        'chronische Entzündung': 'CI',
        'prostatitis + high grade pin': 'CI',
        'prostatitis': 'CI',
        'No tumor': 'N/A',
        'tumorfreies prostatagewebe': 'N/A',
        'High-grade PIN': 'HighPIN',
        'high grade pin': 'HighPIN',
        'Gleason 6': 'GS6',
        'Gleason 7a': 'GS7a',
        'Gleason 7b': 'GS7b',
        'Gleason 8': 'GS8',
        'Gleason 9': 'GS9',
        'Gleason 10': 'GS10'
    }
    return ','.join(class_map.get(c.strip(), c.strip()) for c in class_string.split(','))

result_df['class'] = result_df['class'].apply(normalize_class)

# Select and reorder columns to match segments_copy.csv
column_order = ['study_uid', 'series_uid', 'segment_id', 'comment', 'confidence', 'zone', 'volume', 'region', 'class', 'laterality', 'trackingUID']
result_df = result_df[column_order]

# %%
def is_csPCa(x):
    csPCa_list_ = ['GS7a', 'GS7b', 'GS8', 'GS9', 'GS10']
    return any(word in x for word in csPCa_list_)

result_df['case_csPCa'] = result_df['class'].apply(lambda x: is_csPCa(x) if not pd.isnull(x) else x)

def max_class(x):
    ordered_classes = ['', 'N/A', 'HighPIN', 'CI', 'GS6', 'GS7a', 'GS7b', 'GS8', 'GS9', 'GS10']
    max_class = max([ordered_classes.index(cl) for cl in x.split(',')])
    return ordered_classes[max_class]

result_df['case_class'] = result_df['class'].apply(lambda x: max_class(x) if not pd.isnull(x) else x)

# %%
def get_oid_from_uid(uid):
    study_candidates = orthanc_client.post_tools_lookup(data=uid)
    for i in study_candidates:
        if i['Type'] == 'Study':
            return i['ID']
    return None
                   
for i, row in result_df.iterrows():
    oid = get_oid_from_uid(row['study_uid'])
    # print(oid, row['StudyInstanceUID'])
    result_df.loc[i, 'study_orthanc_id'] = oid

# %%
df_study = pd.read_csv("/data/oleksii/alta-ai.com/alta-ai-orthanc-backup/export20240814/mongo_csv_dump/aggregatedData/study.csv")
healthy = df_study[df_study['diagnoses'] == "{'prostateCancer': {'diagnosis': 'healthy'}}"]

# %%
# Mark the 'healthy' column based on the missing study_orthanc_ids

# alta_ai_lesions[result_df_oid["StudyInstanceUID"].isin(healthy['studyInstanceUID'])]
result_df['healthy'] = np.where(result_df['study_uid'].isin(healthy['studyInstanceUID']), True, False)

# Set empty values for specified columns where study_orthanc_id is NaN
columns_to_empty = ['segment_id', 'comment', 'zone', 'volume', 'region', 'laterality', 'class', 'case_class']

for col in columns_to_empty:
    result_df.loc[result_df['healthy'], col] = ''
    
# healthy = result_df_oid[result_df_oid['study_orthanc_id'].isna()]

# %%
# Save the result to a new CSV file
result_df.to_csv(os.path.join(os.path.dirname(segmentation_path), 'segments_metadata.csv'), index=False, sep=';')

# %%
sftp://141.44.17.135:2200/data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed

# %%
# merge cases
import shutil
# target = "/data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-seg-IDS-fresh"
# destination = "/data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240809"

target = "/data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed"
destination = "/data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed"

# target = "/data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-seg-IDS-fresh-seg"
# destination = "/data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240809-seg"

for soid in os.listdir(target):
    target_path = os.path.join(target, soid)
    destination_path = os.path.join(destination, soid)
    print(target_path, destination_path)
    shutil.move(target_path, destination_path)
# Out:
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/76d45785-ec9fbd19-8e6b2467-238dbe6b-c5ea18f4 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/76d45785-ec9fbd19-8e6b2467-238dbe6b-c5ea18f4
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/da0a601e-840f4712-ed9aa459-a861cfc0-22235948 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/da0a601e-840f4712-ed9aa459-a861cfc0-22235948
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/9be2122f-a42c5e34-6fb3b5a8-646cb445-0a945a70 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/9be2122f-a42c5e34-6fb3b5a8-646cb445-0a945a70
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a3873275-221760f9-157505d0-eaff5e57-abb146dd /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a3873275-221760f9-157505d0-eaff5e57-abb146dd
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a71ba26f-30f43214-50955427-f9344b35-5922ec66 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a71ba26f-30f43214-50955427-f9344b35-5922ec66
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/124b24d3-1a658930-5af1b9af-c87f5127-456f490e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/124b24d3-1a658930-5af1b9af-c87f5127-456f490e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a220caa0-728fcc24-3a895113-55719820-bb116d4e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a220caa0-728fcc24-3a895113-55719820-bb116d4e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4e64aa97-848a9661-4756e1dc-99bdee22-143ad4e8 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4e64aa97-848a9661-4756e1dc-99bdee22-143ad4e8
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/70c1eaee-0308f645-3f4f41c7-2badb66a-ffdc846d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/70c1eaee-0308f645-3f4f41c7-2badb66a-ffdc846d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0ea76b4f-8d652f4d-d1301696-b859d565-f156f729 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0ea76b4f-8d652f4d-d1301696-b859d565-f156f729
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f6ad8d42-62534f28-6b1628dc-d1308b61-122c2006 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f6ad8d42-62534f28-6b1628dc-d1308b61-122c2006
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/28ad4d45-28024ce2-17e1c5f4-1a432a54-de5afdeb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/28ad4d45-28024ce2-17e1c5f4-1a432a54-de5afdeb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/98d67751-53a841d3-f629e3c6-16396984-5ad5964e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/98d67751-53a841d3-f629e3c6-16396984-5ad5964e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/969904ef-65233f21-0e7cf676-a5c9be3a-2b87d53d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/969904ef-65233f21-0e7cf676-a5c9be3a-2b87d53d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5d4dd1f9-e172df95-4be9adf7-8c2e434e-4ad7c463 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5d4dd1f9-e172df95-4be9adf7-8c2e434e-4ad7c463
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/79abb753-2c150927-071c0c6d-59edb758-3a2b1f49 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/79abb753-2c150927-071c0c6d-59edb758-3a2b1f49
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/beb6f50d-ea15c96b-ff6670d6-cf81098c-3a3f421d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/beb6f50d-ea15c96b-ff6670d6-cf81098c-3a3f421d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a06bfae1-5bf91a0d-5f2bf27a-1a684d57-74855344 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a06bfae1-5bf91a0d-5f2bf27a-1a684d57-74855344
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/8b92525e-a31b3d67-e3f166c4-2fe0c7ef-1b46d03f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/8b92525e-a31b3d67-e3f166c4-2fe0c7ef-1b46d03f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b62a5feb-d4bf9db5-b2b8f7b8-c6e056d9-4b772628 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b62a5feb-d4bf9db5-b2b8f7b8-c6e056d9-4b772628
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/dcda6fee-fceb779d-580aeb17-27ad6747-8b5cf6de /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/dcda6fee-fceb779d-580aeb17-27ad6747-8b5cf6de
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/680983c4-0b157a2c-f90f066b-dd2b9d36-54b4e969 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/680983c4-0b157a2c-f90f066b-dd2b9d36-54b4e969
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e52d688b-98dac1de-c5996746-d2fbdec7-3dc8ed87 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e52d688b-98dac1de-c5996746-d2fbdec7-3dc8ed87
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a509a96f-ccb95ae7-aca006ee-044981df-26efe877 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a509a96f-ccb95ae7-aca006ee-044981df-26efe877
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/17179b92-0c590442-ecb59810-d111d1b2-1c8763f3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/17179b92-0c590442-ecb59810-d111d1b2-1c8763f3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4b0eb403-b1fa3d07-41e4663f-4d9571d8-1a9c1c9d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4b0eb403-b1fa3d07-41e4663f-4d9571d8-1a9c1c9d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/7dd72a72-63c83e7b-0c0a9593-a4998759-5c74b0ca /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/7dd72a72-63c83e7b-0c0a9593-a4998759-5c74b0ca
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/71016887-445bdafc-3e684f05-b0cd8d69-8ae20b25 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/71016887-445bdafc-3e684f05-b0cd8d69-8ae20b25
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d27cec04-8f61fa51-cad746c2-c0e1b075-01c682da /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d27cec04-8f61fa51-cad746c2-c0e1b075-01c682da
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/edef5c6c-f1dca07b-cd308511-e7ec617e-d58fe23d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/edef5c6c-f1dca07b-cd308511-e7ec617e-d58fe23d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b4486c84-c5230bd5-96d09b03-be78a381-c33dcfae /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b4486c84-c5230bd5-96d09b03-be78a381-c33dcfae
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/01edd216-ee09af33-cbc85c24-61312a1d-ddd0c134 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/01edd216-ee09af33-cbc85c24-61312a1d-ddd0c134
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/df59ea97-b4849d9c-3f9a89e7-386e48c2-75573c0d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/df59ea97-b4849d9c-3f9a89e7-386e48c2-75573c0d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/33260aa2-4ca50202-6be0c6f3-cc3677aa-ef4c2760 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/33260aa2-4ca50202-6be0c6f3-cc3677aa-ef4c2760
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d352f68c-a6de3ee1-20ee939d-2a6ce8ad-280f57ad /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d352f68c-a6de3ee1-20ee939d-2a6ce8ad-280f57ad
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/839348c6-b781f2bf-e668ca14-57df7c68-1962e5c5 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/839348c6-b781f2bf-e668ca14-57df7c68-1962e5c5
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/442f817b-9f699037-ead71c2c-1f4f6559-ef8fb94b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/442f817b-9f699037-ead71c2c-1f4f6559-ef8fb94b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0d87c79e-da3513c7-f64e336c-350a802c-7e9254d4 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0d87c79e-da3513c7-f64e336c-350a802c-7e9254d4
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/6a0add32-3617a4cd-fe5746c3-0164cc49-236f38e6 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/6a0add32-3617a4cd-fe5746c3-0164cc49-236f38e6
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/7cd3a17f-76caf950-425142c2-36fc874b-b381796b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/7cd3a17f-76caf950-425142c2-36fc874b-b381796b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2cb8f7da-37b56bd2-004998e4-8cf3928d-beec4839 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2cb8f7da-37b56bd2-004998e4-8cf3928d-beec4839
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/699b7a11-db1dae96-f02d89e1-6759c50d-00696850 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/699b7a11-db1dae96-f02d89e1-6759c50d-00696850
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/33b63926-0b5ff1e3-f768cead-63feb806-05ebb681 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/33b63926-0b5ff1e3-f768cead-63feb806-05ebb681
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1005dd14-ee683052-222999fc-c93fe933-1488923d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1005dd14-ee683052-222999fc-c93fe933-1488923d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c354ff1a-4f3eab06-116748bc-5ac123ca-67b155f9 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c354ff1a-4f3eab06-116748bc-5ac123ca-67b155f9
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/cec65dca-d5c6f58d-4bd4165e-612174cb-d58ba2cb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/cec65dca-d5c6f58d-4bd4165e-612174cb-d58ba2cb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/64d88979-5da0cefb-452055fd-4fcc2e2f-26a97b12 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/64d88979-5da0cefb-452055fd-4fcc2e2f-26a97b12
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/49b3db50-0d22e51e-78c6f7e5-6a3fecfb-e8889d98 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/49b3db50-0d22e51e-78c6f7e5-6a3fecfb-e8889d98
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fc4af76c-12eb0f96-0171254f-7e32f6a6-578177da /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fc4af76c-12eb0f96-0171254f-7e32f6a6-578177da
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/420a3614-5c4bfbfa-0c260444-e2dfc9ad-0acc6c9b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/420a3614-5c4bfbfa-0c260444-e2dfc9ad-0acc6c9b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b220f42a-325fd14b-f5b33333-ba99935a-bd59b971 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b220f42a-325fd14b-f5b33333-ba99935a-bd59b971
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/7546e453-78c22710-2d4c4c70-e9874ae6-1cb5be11 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/7546e453-78c22710-2d4c4c70-e9874ae6-1cb5be11
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/484ccadb-319e6f07-7a7dd650-9bfb6880-9a8b297e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/484ccadb-319e6f07-7a7dd650-9bfb6880-9a8b297e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/3ac8956a-69f403dc-4b471121-fba61acf-45cf6b7d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/3ac8956a-69f403dc-4b471121-fba61acf-45cf6b7d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2f9e368b-57aad5f3-452be8d8-62df2c7a-f69428a6 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2f9e368b-57aad5f3-452be8d8-62df2c7a-f69428a6
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2b550ef5-878749a3-e9360fa3-37ae5709-8e144461 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2b550ef5-878749a3-e9360fa3-37ae5709-8e144461
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fc38e55b-03182e65-fa6a7b6d-84cf1c54-b5d08a2c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fc38e55b-03182e65-fa6a7b6d-84cf1c54-b5d08a2c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/dd9fc3a7-a1d0cfb7-1171ed0b-5399d9d2-4f226dcc /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/dd9fc3a7-a1d0cfb7-1171ed0b-5399d9d2-4f226dcc
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f94a6e7f-f5327c03-2d3ff0f0-86f559f8-1b839ebb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f94a6e7f-f5327c03-2d3ff0f0-86f559f8-1b839ebb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/65d67a04-3c7769a0-6eef8571-73253d89-793e9c83 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/65d67a04-3c7769a0-6eef8571-73253d89-793e9c83
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f753e370-d130b414-cc12c674-95eddf3e-90f379cf /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f753e370-d130b414-cc12c674-95eddf3e-90f379cf
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/53bc32e5-0051ff38-214232a4-4b237b38-8c346c45 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/53bc32e5-0051ff38-214232a4-4b237b38-8c346c45
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f08b7ed2-7e88b0d6-17983874-fbadbb78-a56fc048 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f08b7ed2-7e88b0d6-17983874-fbadbb78-a56fc048
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f5d830b0-f7ac81a0-3c7b7808-8477bccc-cc771a5f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f5d830b0-f7ac81a0-3c7b7808-8477bccc-cc771a5f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a4718379-ae74f0ab-1d5f0a47-3a45061c-9e717ea3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a4718379-ae74f0ab-1d5f0a47-3a45061c-9e717ea3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/cb663efd-562fc16e-5976bbed-e58cdd96-0177e083 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/cb663efd-562fc16e-5976bbed-e58cdd96-0177e083
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2133f126-1488562b-1a4f49f8-8cf0c711-b917e8df /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2133f126-1488562b-1a4f49f8-8cf0c711-b917e8df
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5d2334cf-d0b58ee6-3ccfb720-b7420f10-e69734fe /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5d2334cf-d0b58ee6-3ccfb720-b7420f10-e69734fe
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1e6eb4d8-6269a984-e4e66bb9-d6275744-22b6a0d0 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1e6eb4d8-6269a984-e4e66bb9-d6275744-22b6a0d0
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c8bf1ba7-d655d79a-540c2ca4-4c9811bb-09616edb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c8bf1ba7-d655d79a-540c2ca4-4c9811bb-09616edb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/db8bf6b5-a0308a70-7935ae77-589016c2-7df16f13 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/db8bf6b5-a0308a70-7935ae77-589016c2-7df16f13
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d243237a-0ed947b4-46f42172-5b2187a2-f646bafe /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d243237a-0ed947b4-46f42172-5b2187a2-f646bafe
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4df4dabe-8095caf2-5745e819-39e2eae0-bd213e3f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4df4dabe-8095caf2-5745e819-39e2eae0-bd213e3f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/3a2b8157-843c171e-6b8cdb7b-85364c9c-9cc12524 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/3a2b8157-843c171e-6b8cdb7b-85364c9c-9cc12524
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/909a836a-47ceae42-0bae5bfe-44dcb9ea-a9c72ad9 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/909a836a-47ceae42-0bae5bfe-44dcb9ea-a9c72ad9
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/8843ea1c-df0b0cbb-1dd7ff2b-7e4217e5-f4d04a48 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/8843ea1c-df0b0cbb-1dd7ff2b-7e4217e5-f4d04a48
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d613dfab-d95a8fce-5f4dc8bc-e9459d9a-4ef71bb3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d613dfab-d95a8fce-5f4dc8bc-e9459d9a-4ef71bb3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fa151c40-2772848b-e9815f4c-e8913e17-4a533fe1 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fa151c40-2772848b-e9815f4c-e8913e17-4a533fe1
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/61147d34-637bfb46-aa0edb4e-765e25e9-2089b50a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/61147d34-637bfb46-aa0edb4e-765e25e9-2089b50a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/aeb773d1-e825124b-8cf053b0-feade5af-6a4b5564 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/aeb773d1-e825124b-8cf053b0-feade5af-6a4b5564
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5cfb182c-5d10d847-71d79083-03de7258-a110c786 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5cfb182c-5d10d847-71d79083-03de7258-a110c786
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/3dc12671-5e14cf9b-33d6c996-834027ee-a889540c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/3dc12671-5e14cf9b-33d6c996-834027ee-a889540c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/980620b5-8750ba31-e66ff96f-d1674624-401c8cc0 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/980620b5-8750ba31-e66ff96f-d1674624-401c8cc0
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f5fa7f94-bddb2478-494ba59e-f61938d8-8cc32edb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f5fa7f94-bddb2478-494ba59e-f61938d8-8cc32edb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/9b3c7584-329ef8ea-43e5287f-3bece984-764123e9 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/9b3c7584-329ef8ea-43e5287f-3bece984-764123e9
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/79d15ea5-b09c2c68-61ee3a98-fd688a9f-53fb7dec /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/79d15ea5-b09c2c68-61ee3a98-fd688a9f-53fb7dec
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/8b81eed2-de17c48c-c6c8a6c0-e3484af0-0a492ec5 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/8b81eed2-de17c48c-c6c8a6c0-e3484af0-0a492ec5
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/3be110ba-dc61ce02-28c01395-7aa9ef69-135b325a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/3be110ba-dc61ce02-28c01395-7aa9ef69-135b325a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f7a23f58-3c5d0f87-479fe61a-167fd837-f1d4e39e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f7a23f58-3c5d0f87-479fe61a-167fd837-f1d4e39e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/32c653c1-541b58a5-2e11f8be-9858a0e8-76dcd8e7 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/32c653c1-541b58a5-2e11f8be-9858a0e8-76dcd8e7
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c5295dbd-fcd72611-5e382141-2268570b-9c73c327 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c5295dbd-fcd72611-5e382141-2268570b-9c73c327
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/3dcee63a-8c05051b-dccffa80-18ce84fc-fdeeff4c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/3dcee63a-8c05051b-dccffa80-18ce84fc-fdeeff4c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/6eb42f59-0710ff91-c42f90e2-b5af5cd8-5d4f9b50 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/6eb42f59-0710ff91-c42f90e2-b5af5cd8-5d4f9b50
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b3c1824e-219bb8bb-ad5a6d0f-1259112b-7a0da59a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b3c1824e-219bb8bb-ad5a6d0f-1259112b-7a0da59a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0d481429-1649d61c-15a991dd-079a03c7-c32204d6 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0d481429-1649d61c-15a991dd-079a03c7-c32204d6
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/9904804f-4b47815a-e410578b-40e20e21-215e6910 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/9904804f-4b47815a-e410578b-40e20e21-215e6910
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/8da82c9b-bcc2daa5-dae07332-e6fa6b27-fecee064 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/8da82c9b-bcc2daa5-dae07332-e6fa6b27-fecee064
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/369a1573-bb253d6f-1b1c536c-890c4b0a-20cf5657 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/369a1573-bb253d6f-1b1c536c-890c4b0a-20cf5657
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5bc7c8b3-8bc97c83-5d5be9c0-d1537f85-1ec3d31d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5bc7c8b3-8bc97c83-5d5be9c0-d1537f85-1ec3d31d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e6a633eb-125c62bb-109741b8-d8b3b509-b1751ff8 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e6a633eb-125c62bb-109741b8-d8b3b509-b1751ff8
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/623bf144-c54e0572-96be5260-3b4f5f24-89b5c487 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/623bf144-c54e0572-96be5260-3b4f5f24-89b5c487
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f5e3b6f2-6218b1b9-239d4757-14659a7d-85e76c58 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f5e3b6f2-6218b1b9-239d4757-14659a7d-85e76c58
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/79b320b6-dcfa8cfc-e53d48f6-cfa0b78f-0aae37f2 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/79b320b6-dcfa8cfc-e53d48f6-cfa0b78f-0aae37f2
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/7a592f61-016c71ce-0b73c4a6-337a1095-964273ea /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/7a592f61-016c71ce-0b73c4a6-337a1095-964273ea
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/73ed0979-0c0bb800-e1f2b0ba-47c8de4e-694d5cd6 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/73ed0979-0c0bb800-e1f2b0ba-47c8de4e-694d5cd6
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/6d9d51be-c84da2c8-dc3ccaed-a902f71f-ea898821 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/6d9d51be-c84da2c8-dc3ccaed-a902f71f-ea898821
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/93d57e99-b3f17eff-5be82b0e-24c147f5-f4ffdf94 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/93d57e99-b3f17eff-5be82b0e-24c147f5-f4ffdf94
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/bd730fca-ba5eb713-0ee9ab50-d5434681-4f15d17d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/bd730fca-ba5eb713-0ee9ab50-d5434681-4f15d17d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4f1cac4b-4ae042fd-75691720-7b9d6e3e-b089342c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4f1cac4b-4ae042fd-75691720-7b9d6e3e-b089342c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/93e53290-a04d0d55-e33c7798-de3c46e8-2c83b75b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/93e53290-a04d0d55-e33c7798-de3c46e8-2c83b75b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/261d2f9c-795670fb-07bec1f7-872558b1-f7cf30bc /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/261d2f9c-795670fb-07bec1f7-872558b1-f7cf30bc
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/cf46effa-41fa9d48-86d00b20-21b08b79-e29c0695 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/cf46effa-41fa9d48-86d00b20-21b08b79-e29c0695
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/016633aa-61193014-3381caf6-27c291af-71d991c3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/016633aa-61193014-3381caf6-27c291af-71d991c3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/ee0430f5-ccf7bd06-1891a88d-f65cdec4-5f0db378 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/ee0430f5-ccf7bd06-1891a88d-f65cdec4-5f0db378
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/045e74b1-ca505b50-c4dcafc1-6d2f0f2f-92bba647 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/045e74b1-ca505b50-c4dcafc1-6d2f0f2f-92bba647
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/35a9176a-ba254ec7-82755d42-6877fadd-8d92fd3a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/35a9176a-ba254ec7-82755d42-6877fadd-8d92fd3a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/80d27dc0-961de1af-0ea04639-bc963b7a-d25a9288 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/80d27dc0-961de1af-0ea04639-bc963b7a-d25a9288
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/8576592e-a784d0c6-e48359d7-97ef703a-268ab7e3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/8576592e-a784d0c6-e48359d7-97ef703a-268ab7e3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/ca63cff3-32020e85-1b7007c8-a40b2a42-666965ec /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/ca63cff3-32020e85-1b7007c8-a40b2a42-666965ec
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/ca63596e-83fca8bc-5548299c-69c5433d-3c36b7bb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/ca63596e-83fca8bc-5548299c-69c5433d-3c36b7bb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c47baf9f-16d365c1-6a57ad13-13276419-82404d4e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c47baf9f-16d365c1-6a57ad13-13276419-82404d4e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f7abd4fe-e795e4c1-3b666b37-bb735633-8b9fca13 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f7abd4fe-e795e4c1-3b666b37-bb735633-8b9fca13
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/dbe63a62-21385c92-7b3c6e3e-f9f35989-2cdad86f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/dbe63a62-21385c92-7b3c6e3e-f9f35989-2cdad86f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/07b88a3f-748b3837-f2a2bfd1-68888b3d-043088e3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/07b88a3f-748b3837-f2a2bfd1-68888b3d-043088e3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/106bea5e-aad769c3-9aceb858-114b1c5b-48886ef3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/106bea5e-aad769c3-9aceb858-114b1c5b-48886ef3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4a686067-a507df27-c1e5dc5c-d108c2a7-7bd295d5 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4a686067-a507df27-c1e5dc5c-d108c2a7-7bd295d5
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fb5def56-f6dcd23d-e381d592-b2627109-c87fce4a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fb5def56-f6dcd23d-e381d592-b2627109-c87fce4a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a78ecdaf-e20d0dbd-f3f939a7-3e78a850-70d438ef /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a78ecdaf-e20d0dbd-f3f939a7-3e78a850-70d438ef
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c0304162-67951d40-cc45ec60-d4847052-f29aaad7 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c0304162-67951d40-cc45ec60-d4847052-f29aaad7
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/47f2910b-6ada9d98-a616cc2a-7811f7b8-e95760ca /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/47f2910b-6ada9d98-a616cc2a-7811f7b8-e95760ca
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0927124e-ef1042a1-60fec082-36f434dd-b3ca6b97 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0927124e-ef1042a1-60fec082-36f434dd-b3ca6b97
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1d77103e-7f2822eb-3582d2ae-dcf602ce-c9fc1b42 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1d77103e-7f2822eb-3582d2ae-dcf602ce-c9fc1b42
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5ddfeccd-d359aa5d-16b14af7-4bfd23ea-5b870e9f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5ddfeccd-d359aa5d-16b14af7-4bfd23ea-5b870e9f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/eaccacc3-26959fc7-91dcf683-385555dd-748c8521 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/eaccacc3-26959fc7-91dcf683-385555dd-748c8521
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1c69c6f3-981830b3-72d8e84c-cfd7984d-c88dce25 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1c69c6f3-981830b3-72d8e84c-cfd7984d-c88dce25
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d635e0c4-b23d88d0-0f6b645b-22c98cf7-0c2d8f9b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d635e0c4-b23d88d0-0f6b645b-22c98cf7-0c2d8f9b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/ee621407-6a32ac7e-9e62483b-e0baacb4-6672b982 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/ee621407-6a32ac7e-9e62483b-e0baacb4-6672b982
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f2d08a02-b3e9e566-ee0a4ebc-45eefc30-8733d4aa /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f2d08a02-b3e9e566-ee0a4ebc-45eefc30-8733d4aa
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/353adcf9-f0682381-b61817ed-2ffba8e8-d17fda7e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/353adcf9-f0682381-b61817ed-2ffba8e8-d17fda7e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/40bd0841-405faffd-87efbbaf-501c2b02-35278486 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/40bd0841-405faffd-87efbbaf-501c2b02-35278486
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/65cacf5c-fc16239f-3b86c8da-f3d5773f-5f292200 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/65cacf5c-fc16239f-3b86c8da-f3d5773f-5f292200
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2b3daf74-6cce34de-42ef37c2-39de7611-94c7a56e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2b3daf74-6cce34de-42ef37c2-39de7611-94c7a56e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4f559182-7597b7bc-ec0e8284-fcc665cd-7fed46f7 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4f559182-7597b7bc-ec0e8284-fcc665cd-7fed46f7
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0b069f91-0fbe3627-1cc4f8d3-e1eede7f-818fb584 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0b069f91-0fbe3627-1cc4f8d3-e1eede7f-818fb584
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/90ca4618-94cbb149-f640c241-e8fea374-fe4c98e2 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/90ca4618-94cbb149-f640c241-e8fea374-fe4c98e2
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c063e3b4-9bf1292f-4acc0114-2fc32e87-da6f1f6c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c063e3b4-9bf1292f-4acc0114-2fc32e87-da6f1f6c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1f47caa6-108dfa37-a7d241a2-b93dcf2c-5c3bdb36 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1f47caa6-108dfa37-a7d241a2-b93dcf2c-5c3bdb36
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e42e3bdf-19964f9a-3f65f52d-1737b964-4f5dc2a6 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e42e3bdf-19964f9a-3f65f52d-1737b964-4f5dc2a6
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a998868a-35a5d7cb-1cc838ea-15d60156-3d445f62 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a998868a-35a5d7cb-1cc838ea-15d60156-3d445f62
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/9c361c13-1cab40df-e44f6aee-adfe52fc-6e06a8a9 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/9c361c13-1cab40df-e44f6aee-adfe52fc-6e06a8a9
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/086a2e71-ff0d8879-84b3c207-aceb22f2-3f711274 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/086a2e71-ff0d8879-84b3c207-aceb22f2-3f711274
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/3b1f7116-6b0d9753-75ee6806-c83c7b80-132b5c69 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/3b1f7116-6b0d9753-75ee6806-c83c7b80-132b5c69
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/df2ed2a1-2986cc9f-071c640a-482c89e1-3445ab1a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/df2ed2a1-2986cc9f-071c640a-482c89e1-3445ab1a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b16d2620-6ac9d3d0-9bbacb08-871e44a2-48403f0d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b16d2620-6ac9d3d0-9bbacb08-871e44a2-48403f0d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f4b057a2-d3ee7f40-3418befc-75aa46bc-f751e387 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f4b057a2-d3ee7f40-3418befc-75aa46bc-f751e387
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e4107a3b-243e5020-13a8546d-d889b35e-8a971103 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e4107a3b-243e5020-13a8546d-d889b35e-8a971103
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0266a233-d71ad211-bd4ab3d8-bec8639a-1f4b5497 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0266a233-d71ad211-bd4ab3d8-bec8639a-1f4b5497
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1017236a-a24d237c-ea39abb2-fc02f25d-617ffc60 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1017236a-a24d237c-ea39abb2-fc02f25d-617ffc60
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5cc5416e-e6608326-93861f8e-3bef8c9e-931c7b1c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5cc5416e-e6608326-93861f8e-3bef8c9e-931c7b1c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a6195bb2-2265e1a5-44cad9dc-60054f26-25eab570 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a6195bb2-2265e1a5-44cad9dc-60054f26-25eab570
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/7bbad440-b94ead99-58c4dd3c-b413f312-498a2dbe /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/7bbad440-b94ead99-58c4dd3c-b413f312-498a2dbe
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/6c7537e8-9be9b61f-2ca133d6-114e4872-e432e20a /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/6c7537e8-9be9b61f-2ca133d6-114e4872-e432e20a
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0fef3166-545ff5a9-ae958a89-9a3cf517-b4943ad5 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0fef3166-545ff5a9-ae958a89-9a3cf517-b4943ad5
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d4680300-6a1d6c76-9ab7dc44-7f9860ff-986f51e3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d4680300-6a1d6c76-9ab7dc44-7f9860ff-986f51e3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0d8ed514-66970a16-f12d7473-598c40b0-a7b7e31f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0d8ed514-66970a16-f12d7473-598c40b0-a7b7e31f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a864e13e-cb9bb26c-8a41400b-a3a3d4c7-a647648b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a864e13e-cb9bb26c-8a41400b-a3a3d4c7-a647648b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/370c7a00-65ed01f1-aae36da9-f8919c24-d2bede42 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/370c7a00-65ed01f1-aae36da9-f8919c24-d2bede42
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d36abe9a-b3e8359b-88f24bf9-b867f8fb-11e0742c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d36abe9a-b3e8359b-88f24bf9-b867f8fb-11e0742c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2c3581ee-0d7653d7-01c0c797-3a48d6cf-f3f73048 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2c3581ee-0d7653d7-01c0c797-3a48d6cf-f3f73048
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/da20b33f-8b0d9371-e60ea2f9-4a310df6-b139ea52 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/da20b33f-8b0d9371-e60ea2f9-4a310df6-b139ea52
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/2b2d31dc-7c592c77-2144bee0-29228868-cf4610f0 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/2b2d31dc-7c592c77-2144bee0-29228868-cf4610f0
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/25c93dba-d86536e1-57592084-1a1b7081-06d77c96 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/25c93dba-d86536e1-57592084-1a1b7081-06d77c96
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/80217127-ad0a8dc1-804f198c-e3d976f5-22970f8c /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/80217127-ad0a8dc1-804f198c-e3d976f5-22970f8c
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fc41bc52-7a18f920-f07c7ade-ce437dcd-078d8d8f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fc41bc52-7a18f920-f07c7ade-ce437dcd-078d8d8f
# ...
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a2666522-da974bf4-ac5910b7-6724ea49-3e0244d8 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a2666522-da974bf4-ac5910b7-6724ea49-3e0244d8
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/93430b7b-4da1c0d6-cd4805f9-3cc1d369-4d5ffeeb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/93430b7b-4da1c0d6-cd4805f9-3cc1d369-4d5ffeeb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0f860e92-958362b0-b28acdb1-f698bf2d-b47ce894 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0f860e92-958362b0-b28acdb1-f698bf2d-b47ce894
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d443b22d-f4c6f73c-6c675bb3-d16bdb70-77142c98 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d443b22d-f4c6f73c-6c675bb3-d16bdb70-77142c98
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e3b948de-0b012ecd-5ace7db4-e714b91c-dd2c1381 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e3b948de-0b012ecd-5ace7db4-e714b91c-dd2c1381
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e2a25799-26520491-7af8cd4f-d31a52c9-be30afaf /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e2a25799-26520491-7af8cd4f-d31a52c9-be30afaf
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/24752f77-5741dd05-8922932c-6b430334-92d2f59d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/24752f77-5741dd05-8922932c-6b430334-92d2f59d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b1611f02-cf6f631f-4bc8ea97-61e2d795-751ecd51 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b1611f02-cf6f631f-4bc8ea97-61e2d795-751ecd51
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5d546c49-f9c908ff-c533225e-db847d2e-de46bc95 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5d546c49-f9c908ff-c533225e-db847d2e-de46bc95
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fb6b9937-32514036-59fb3123-44f7d9a5-bedcabfb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fb6b9937-32514036-59fb3123-44f7d9a5-bedcabfb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/43cc525b-6fa70a94-df907a1d-5a815817-7e7e1cc8 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/43cc525b-6fa70a94-df907a1d-5a815817-7e7e1cc8
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b9518931-e8a5f3b7-a2832441-d0f29312-3bfee412 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b9518931-e8a5f3b7-a2832441-d0f29312-3bfee412
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/b501ca20-442beb2c-4ea7ccd3-51b16f43-16397fbf /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/b501ca20-442beb2c-4ea7ccd3-51b16f43-16397fbf
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4874e429-fc0b3c25-7aeee3fd-190dfed0-7bc4c3b3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4874e429-fc0b3c25-7aeee3fd-190dfed0-7bc4c3b3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/9081d528-cff954cd-12287a95-748bb31f-1186f66d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/9081d528-cff954cd-12287a95-748bb31f-1186f66d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a5ceec34-3581ab9f-2ce959f4-1f764692-ec09d3a9 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a5ceec34-3581ab9f-2ce959f4-1f764692-ec09d3a9
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/45121caa-195bc18d-b977680d-489b2090-d7ef5d0f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/45121caa-195bc18d-b977680d-489b2090-d7ef5d0f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/1c941cc5-838db8fa-0ba181a8-34f8f5f8-17c8e4c7 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/1c941cc5-838db8fa-0ba181a8-34f8f5f8-17c8e4c7
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/6d78e6d1-e2207d41-ebe3696c-1d25b83b-370d6021 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/6d78e6d1-e2207d41-ebe3696c-1d25b83b-370d6021
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/747cf9f9-c3ca826a-995b6ebc-ec67613e-758e2fa1 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/747cf9f9-c3ca826a-995b6ebc-ec67613e-758e2fa1
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/731d7087-830aec43-c35bb748-e68e91d8-9b2b2a4e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/731d7087-830aec43-c35bb748-e68e91d8-9b2b2a4e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/f1f79017-fc048ae1-13367625-54d6a469-0bdda0e3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/f1f79017-fc048ae1-13367625-54d6a469-0bdda0e3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/fae6e334-8562855b-f947fe39-93587a48-50635486 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/fae6e334-8562855b-f947fe39-93587a48-50635486
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/d9bad649-3ed33cd8-5dc36191-9978eb88-94d3a976 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/d9bad649-3ed33cd8-5dc36191-9978eb88-94d3a976
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/6379ba25-e12b79a5-c1344f89-b35965c5-c1261509 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/6379ba25-e12b79a5-c1344f89-b35965c5-c1261509
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/460cfdb4-12a183c5-7d30f96d-70fe1dcc-0d0ea9fb /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/460cfdb4-12a183c5-7d30f96d-70fe1dcc-0d0ea9fb
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/af14aa0a-a3f650b0-fdf6d628-3206c840-cf4ffaac /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/af14aa0a-a3f650b0-fdf6d628-3206c840-cf4ffaac
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a837c03a-34bec1f8-01b298bb-a77a0878-02d69684 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a837c03a-34bec1f8-01b298bb-a77a0878-02d69684
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/eaf9d281-f3bfa2f8-3a3eb346-55ec2688-0fc08193 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/eaf9d281-f3bfa2f8-3a3eb346-55ec2688-0fc08193
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/87c0d2e1-e72c5faf-a76809b3-111e975f-f7b27c51 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/87c0d2e1-e72c5faf-a76809b3-111e975f-f7b27c51
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/849d80cb-bd65d801-ffb662d5-b85dd798-c40b7ec2 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/849d80cb-bd65d801-ffb662d5-b85dd798-c40b7ec2
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/61db5086-39965eb4-b702eab7-e00742da-aeb4a522 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/61db5086-39965eb4-b702eab7-e00742da-aeb4a522
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/10348bfc-0758b8fa-b69fe70c-df38fc12-85436560 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/10348bfc-0758b8fa-b69fe70c-df38fc12-85436560
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/727a4979-3252f236-37e37800-5094e6dd-ee35ce6b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/727a4979-3252f236-37e37800-5094e6dd-ee35ce6b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5ff69109-40793bfb-84d4db9b-9c5de473-f1ec527f /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5ff69109-40793bfb-84d4db9b-9c5de473-f1ec527f
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/28943f44-ff88f200-959e713a-2dba70b2-eb9d10f0 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/28943f44-ff88f200-959e713a-2dba70b2-eb9d10f0
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/7af6715f-c08172a2-480d31a9-5dcc03c2-afe5c2d2 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/7af6715f-c08172a2-480d31a9-5dcc03c2-afe5c2d2
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/9af1762b-f33439a2-199e8eb3-3bcd7724-eb378614 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/9af1762b-f33439a2-199e8eb3-3bcd7724-eb378614
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4afe2388-b2b275a8-00cfce23-2101dcfc-ab45a6cd /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4afe2388-b2b275a8-00cfce23-2101dcfc-ab45a6cd
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0c7773bb-12cc21e7-c6f33aaa-dec178e3-03aea437 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0c7773bb-12cc21e7-c6f33aaa-dec178e3-03aea437
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/78620c88-2d7754ba-472589cb-07623b46-7da4f57b /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/78620c88-2d7754ba-472589cb-07623b46-7da4f57b
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/ec3149fa-13cfb5a7-df878c5f-1b41df63-149f2dbe /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/ec3149fa-13cfb5a7-df878c5f-1b41df63-149f2dbe
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/ae1e8daf-1bdff498-661cda14-2d16f3e3-416a8ecd /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/ae1e8daf-1bdff498-661cda14-2d16f3e3-416a8ecd
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/44cf4caf-b0b19cdd-0be05075-f91bbde0-12a2378d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/44cf4caf-b0b19cdd-0be05075-f91bbde0-12a2378d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/31166877-b3c1c8ea-540ea3a3-93f7f100-56c689f0 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/31166877-b3c1c8ea-540ea3a3-93f7f100-56c689f0
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/5d10ba50-14788365-16d6ef80-299cb4fc-a46b4ab2 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/5d10ba50-14788365-16d6ef80-299cb4fc-a46b4ab2
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/e4ec1b59-dbedcc37-d2ad6d1e-d6d86458-998ae090 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/e4ec1b59-dbedcc37-d2ad6d1e-d6d86458-998ae090
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/a91c61db-74a8bde4-21704068-78013e0c-6276bed5 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/a91c61db-74a8bde4-21704068-78013e0c-6276bed5
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/541c81c5-57ef249d-18a9fc30-a89fb266-80e8ccb3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/541c81c5-57ef249d-18a9fc30-a89fb266-80e8ccb3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4f75bc48-de6f03e7-221f384d-0bb5831e-89422ef3 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4f75bc48-de6f03e7-221f384d-0bb5831e-89422ef3
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/0fcbfbc1-f9cdce41-299e2a18-d398857c-b67c418e /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/0fcbfbc1-f9cdce41-299e2a18-d398857c-b67c418e
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/993c273e-6fae30cc-0ca9a302-e63471f2-a5b9edcd /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/993c273e-6fae30cc-0ca9a302-e63471f2-a5b9edcd
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/cbf9953c-31c097fc-c42e9922-72cfa30e-fe5eec0d /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/cbf9953c-31c097fc-c42e9922-72cfa30e-fe5eec0d
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/4d9fd438-6242d564-1015af11-ea1dc43f-1fc124b5 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/4d9fd438-6242d564-1015af11-ea1dc43f-1fc124b5
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/05e9aed9-e39a6d25-07c1f0cc-3c96ee24-83698dcc /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/05e9aed9-e39a6d25-07c1f0cc-3c96ee24-83698dcc
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/aa64ed6b-19d313b6-ac9fa304-494b6f8a-6a07db88 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/aa64ed6b-19d313b6-ac9fa304-494b6f8a-6a07db88
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/c47224f3-c7b5ea61-8bcfcdca-791f8066-0bd2bac0 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/c47224f3-c7b5ea61-8bcfcdca-791f8066-0bd2bac0
# /data/oleksii/Prostate-Lesion-Datasets-NRRDS/ALTA-Lesion-Dataset-alta_ai-export20240814-preprocessed/421ef7c6-7239f574-87a7b92c-0253fe71-6bdcf9b9 /data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/ALTA-Lesion-Dataset-preprocessed/421ef7c6-7239f574-87a7b92c-0253fe71-6bdcf9b9

# %%
# checking if the target of the segmentation matches the trackingUID in list
# use dicom_oid to access right dicom
import glob
import pydicom
lesions = glob.glob("/data/oleksii/alta-ai.com/alta-ai-orthanc-backup/export20240809/prostate_lesion/ProcessingState.PERFECT/*/seg.dcm")

for i, l in enumerate(lesions):
    orthancID = l.split("/")[-2]
    print(result_df_oid[result_df_oid['dicom_oid'] == orthancID]['trackingUID'].values)
    dataset = pydicom.dcmread(l)
    for segment in dataset[(0x0062, 0x0002)]:
        print(segment[(0x0062, 0x0020)])
        print(segment[(0x0062, 0x0021)])

# %%
# merge tables
df1 = pd.read_csv("/data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/lesion_dataset_1909_20240131_OB.csv", sep=';')
df2 = pd.read_csv("/data/oleksii/alta-ai.com/alta-ai-orthanc-backup/export20240814/mongo_csv_dump/aggregatedData/segments_metadata_preprocessed.csv", sep=';')

current_sequence_map = pd.read_csv("/home/oleksii/projects/ohif-orthanc-postgres-docker/sequence_mapping/sequence_mapping_13681_studies_20240807.csv",
                                   sep=';')
alta_ai_lesions_seq = pd.merge(df2, current_sequence_map, on='study_orthanc_id', how='left')

from datetime import datetime

# Get today's date as a string in the format yyyymmdd
today = datetime.today().strftime('%Y%m%d')

df = pd.concat([df1, df2])
df.to_csv(f"/data/oleksii/Prostate-Lesion-Datasets-NRRDS/train/lesion_dataset_{len(df)}_{today}_OB.csv", sep=';', index=False)
